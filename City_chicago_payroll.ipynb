# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/tuhinalambijoy/Downloads/Current_Employee_Names__Salaries__and_Position_Titles.csv')

# %%
df
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 0                     F           Salary            NaN    $107790.00
# ...

# %%
df.describe().round(2)
# Out:
#        Typical Hours
# count        7883.00
# mean           34.70
# std             9.15
# min            10.00
# 25%            20.00
# 50%            40.00
# 75%            40.00
# max            40.00

# %%
print("Max value in typical hours :",df['Typical Hours'].max())
# Out:
# Max value in typical hours : 40.0

# %%
df.head()
# Out:
#                Name      Job Titles Department Full or Part-Time  \
# 0  ALLISON,  PAUL W      LIEUTENANT       FIRE                 F
# 1   BRUNO,  KEVIN D        SERGEANT     POLICE                 F
# 2   COOPER,  JOHN E  LIEUTENANT-EMT       FIRE                 F
# 3  CRESPO,  VILMA I      STAFF ASST        LAW                 F
# 4  DOLAN,  ROBERT J        SERGEANT     POLICE                 F
#
#   Salary or Hourly  Typical Hours Annual Salary Hourly Rate
# 0           Salary            NaN    $107790.00         NaN
# 1           Salary            NaN    $104628.00         NaN
# 2           Salary            NaN    $114324.00         NaN
# 3           Salary            NaN     $76932.00         NaN
# 4           Salary            NaN    $111474.00         NaN

# %%
df['Salary or Hourly'].value_counts()
# Out:
# Salary or Hourly
# Salary    24775
# Hourly     7883
# Name: count, dtype: int64

# %%
df.groupby('Salary or Hourly').count()
# Out:
#                    Name  Job Titles  Department  Full or Part-Time  \
# Salary or Hourly
# Hourly             7883        7883        7883               7883
# Salary            24775       24775       24775              24775
#
#                   Typical Hours  Annual Salary  Hourly Rate
# Salary or Hourly
# Hourly                     7883              0         7883
# Salary                        0          24775            0

# %%
df.groupby('Salary or Hourly')[['Salary or Hourly']].count()
# Out:
#                   Salary or Hourly
# Salary or Hourly
# Hourly                        7883
# Salary                       24775

# %%
df['Department'].value_counts().head(1)
# Out:
# Department
# POLICE    12973
# Name: count, dtype: int64

# %%
df.groupby(['Department']).value_counts(['Salary or Hourly'])
# Out:
# Department             Salary or Hourly
# ADMIN HEARNG           Salary                 38
# ANIMAL CONTRL          Salary                 57
#                        Hourly                 16
# AVIATION               Hourly               1056
#                        Salary                556
# BOARD OF ELECTION      Salary                112
# BOARD OF ETHICS        Salary                  8
# BUDGET & MGMT          Salary                 43
#                        Hourly                  1
# BUILDINGS              Salary                266
# BUSINESS AFFAIRS       Salary                160
#                        Hourly                  8
# CITY CLERK             Salary                 82
#                        Hourly                  3
# CITY COUNCIL           Salary                348
#                        Hourly                 52
# COMMUNITY DEVELOPMENT  Salary                210
#                        Hourly                  4
# ...

# %%
df[df["Department"].isin(["Police"])]
# Out:
# Empty DataFrame
# Columns: [Name, Job Titles, Department, Full or Part-Time, Salary or Hourly, Typical Hours, Annual Salary, Hourly Rate]
# Index: []

# %%
df[df['Department']=='POLICE']['Salary or Hourly'].value_counts()
# Out:
# Salary or Hourly
# Salary    12941
# Hourly       32
# Name: count, dtype: int64

# %%
df['Salary']=df['Annual Salary'].str.replace('$','').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32658 entries, 0 to 32657
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               32658 non-null  object
#  1   Job Titles         32658 non-null  object
#  2   Department         32658 non-null  object
#  3   Full or Part-Time  32658 non-null  object
#  4   Salary or Hourly   32658 non-null  object
#  5   Typical Hours      7883 non-null   float64
#  6   Annual Salary      24775 non-null  object
#  7   Hourly Rate        7883 non-null   object
#  8   Salary             24775 non-null  float64
# dtypes: float64(2), object(7)
# memory usage: 2.2+ MB

# %%
df['Salary'].max()
# Out:
# np.float64(300000.0)

# %%
df[df['Salary']==df['Salary'].max()][["Name","Salary"]]
# Out:
#                   Name    Salary
# 8310  EVANS,  GINGER S  300000.0

# %%
df['Salary'].idxmin()
# Out:
# 15387

# %%
df.to_csv('/Users/tuhinalambijoy/Downloads/Chicago.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32658 entries, 0 to 32657
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               32658 non-null  object
#  1   Job Titles         32658 non-null  object
#  2   Department         32658 non-null  object
#  3   Full or Part-Time  32658 non-null  object
#  4   Salary or Hourly   32658 non-null  object
#  5   Typical Hours      7883 non-null   float64
#  6   Annual Salary      24775 non-null  object
#  7   Hourly Rate        7883 non-null   object
#  8   Salary             24775 non-null  float64
# dtypes: float64(2), object(7)
# memory usage: 2.2+ MB

# %% [markdown]
# Find who has minimum salary

# %%
df[df['Salary']==df['Salary'].min()][["Name","Salary"]]
# Out:
#                  Name  Salary
# 15387  KOCH,  STEVEN     0.96

# %% [markdown]
# Find who has maximum salary

# %%
df[df['Salary']==df["Salary"].max()][["Name","Salary"]]
# Out:
#                   Name    Salary
# 8310  EVANS,  GINGER S  300000.0

# %% [markdown]
# Find who has designation officer in their title

# %%
df[df['Job Titles'].str.contains('Officer',case=False)]
# Out:
#                         Name      Job Titles Department Full or Part-Time  \
# 8           ESTRADA,  LUIS F  POLICE OFFICER     POLICE                 F
# 12        FREELON,  CHERYL N  POLICE OFFICER     POLICE                 F
# 15         HARRIS,  DANIEL J  POLICE OFFICER     POLICE                 F
# 27             MOORE,  TED D  POLICE OFFICER     POLICE                 F
# 35        ROBINSON,  HAROLD   POLICE OFFICER     POLICE                 F
# ...                      ...             ...        ...               ...
# 32652       ZYGMUNT,  DAWID   POLICE OFFICER     POLICE                 F
# 32653     ZYGOWICZ,  PETER J  POLICE OFFICER     POLICE                 F
# 32654  ZYLINSKA,  KATARZYNA   POLICE OFFICER     POLICE                 F
# 32655      ZYMANTAS,  MARK E  POLICE OFFICER     POLICE                 F
# 32656    ZYRKOWSKI,  CARLO E  POLICE OFFICER     POLICE                 F
#
#       Salary or Hourly  Typical Hours Annual Salary Hourly Rate   Salary
# ...

# %%
df.isnull().sum()
# Out:
# Name                     0
# Job Titles               0
# Department               0
# Full or Part-Time        0
# Salary or Hourly         0
# Typical Hours        24775
# Annual Salary         7883
# Hourly Rate          24775
# Salary                7883
# dtype: int64

# %%
df.isnull().any(axis=1).sum()
# Out:
# np.int64(32658)

# %% [markdown]
# Filling the null values for the salary colum using mean

# %%
df['Salary']=df['Salary'].fillna(df['Salary'].mean())
df[['Salary']].mean()
# Out:
# Salary    87512.780241
# dtype: float64

# %%
df['Salary'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.sort_values(by="Salary",ascending=True)['Salary']
# Out:
# 15387         0.96
# 3051      10008.00
# 28860     12840.00
# 6573      13002.00
# 28756     15000.00
#            ...
# 9062     197736.00
# 26028    202728.00
# 8079     216210.00
# 13999    260004.00
# 8310     300000.00
# Name: Salary, Length: 32658, dtype: float64

# %% [markdown]
# fill the null valus by the mode

# %%
df['Salary']=df['Salary'].fillna(df['Salary'].mode())
df[['Salary']]
# Out:
#          Salary
# 0      107790.0
# 1      104628.0
# 2      114324.0
# 3       76932.0
# 4      111474.0
# ...         ...
# 32653   90024.0
# 32654   48078.0
# 32655   87006.0
# 32656   93354.0
# 32657  115932.0
#
# [32658 rows x 1 columns]

# %%
df[["Salary"]].mean()
# Out:
# Salary    87512.780241
# dtype: float64

# %% [markdown]
# find who has department police and salary hourly

# %%
df.head()
# Out:
#                Name      Job Titles Department Full or Part-Time  \
# 0  ALLISON,  PAUL W      LIEUTENANT       FIRE                 F
# 1   BRUNO,  KEVIN D        SERGEANT     POLICE                 F
# 2   COOPER,  JOHN E  LIEUTENANT-EMT       FIRE                 F
# 3  CRESPO,  VILMA I      STAFF ASST        LAW                 F
# 4  DOLAN,  ROBERT J        SERGEANT     POLICE                 F
#
#   Salary or Hourly  Typical Hours Annual Salary Hourly Rate    Salary
# 0           Salary            NaN    $107790.00         NaN  107790.0
# 1           Salary            NaN    $104628.00         NaN  104628.0
# 2           Salary            NaN    $114324.00         NaN  114324.0
# 3           Salary            NaN     $76932.00         NaN   76932.0
# 4           Salary            NaN    $111474.00         NaN  111474.0
